# %% [markdown]
# ## OSRM (Open Source Routing Machine)
#
# **Author**: SADDIK Imad
# <br/>
# **Date**: 26/12/2024
#
# ---

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Route service](#toc1_)
#   - [Setup](#toc1_1_)
#   - [Using the service](#toc1_2_)
#     - [General options](#toc1_2_1_)
#     - [Making the request](#toc1_2_2_)
#     - [Plotting the path](#toc1_2_3_)
#     - [Exploring legs](#toc1_2_4_)
#     - [Exploring the intersections](#toc1_2_5_)
#     - [Exploring the cost of the route](#toc1_2_6_)
#     - [Alternative routes](#toc1_2_7_)

# %% [markdown]
# ---

# %% [markdown]
# # <a id='toc1_'></a>[Route service](#toc0_)

# %% [markdown]
# Use this service if you want to find the fastest route between coordinates. Read more about it [here](https://project-osrm.org/docs/v5.24.0/api/?language=cURL#route-service).

# %% [markdown]
# ## <a id='toc1_1_'></a>[Setup](#toc0_)

# %% [markdown]
# I selected four points from the map, designating one as the center. Using the `Folium` package, I will visualize these points on the map.

# %%
import folium

from folium import Map
from pydantic import BaseModel


class Point(BaseModel):
    latitude: float
    longitude: float


def get_folium_map(center_point: Point, points: list[Point], zoom_level: int = 14) -> Map:
    folium_map = folium.Map(
        location=[center_point.latitude, center_point.longitude], zoom_start=zoom_level)

    for point in points:
        folium.Marker(location=[point.latitude, point.longitude],
                      popup='Point').add_to(folium_map)

    return folium_map


point_1 = Point(latitude=33.89264295626195, longitude=-5.500305816538693)
point_2 = Point(latitude=33.899915132942326, longitude=-5.520818749583605)
point_3 = Point(latitude=33.891645357611154, longitude=-5.5397637571355105)
center_point = Point(latitude=33.89565560255, longitude=-5.522530349727877)

folium_map = get_folium_map(center_point, [point_1, point_2, point_3])
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6762dced66fd14fac67b6be8e790d326 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6762dced66fd14fac67b6be8e790d326&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6762dced66fd14fac67b6be8e790d326 = L.map(
#                 &quot;map_6762dced66fd14fac67b6be8e790d326&quot;,
#                 {
#                     center: [33.89565560255, -5.522530349727877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1353a3fe6d9a15fbf379a50d690b553 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1353a3fe6d9a15fbf379a50d690b553.addTo(map_6762dced66fd14fac67b6be8e790d326);
#
#
#             var marker_1c6b07c32dd0fc8fcead0e5a397b7c40 = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_6762dced66fd14fac67b6be8e790d326);
#
#
#         var popup_d6215e8703c14998fd0620d790caee90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91489fe78bccbdd67e5a67202d179287 = $(`&lt;div id=&quot;html_91489fe78bccbdd67e5a67202d179287&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d6215e8703c14998fd0620d790caee90.setContent(html_91489fe78bccbdd67e5a67202d179287);
#
#
#
#         marker_1c6b07c32dd0fc8fcead0e5a397b7c40.bindPopup(popup_d6215e8703c14998fd0620d790caee90)
#         ;
#
#
#
#
#             var marker_ca371a77f9d636ecb277b847d3ef14be = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_6762dced66fd14fac67b6be8e790d326);
#
#
#         var popup_861c4ab89ed644faeb3e60b54299456d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec5fd524446ba3b02113d371ef85b88d = $(`&lt;div id=&quot;html_ec5fd524446ba3b02113d371ef85b88d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_861c4ab89ed644faeb3e60b54299456d.setContent(html_ec5fd524446ba3b02113d371ef85b88d);
#
#
#
#         marker_ca371a77f9d636ecb277b847d3ef14be.bindPopup(popup_861c4ab89ed644faeb3e60b54299456d)
#         ;
#
#
#
#
#             var marker_7a48efcb3c99eb2fb93a593e5a4f1194 = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_6762dced66fd14fac67b6be8e790d326);
#
#
#         var popup_2f94c4606f2d9fd7ea325a492c6dd83c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1eb6c26ab412bfbe8dcaa9bc97dd5137 = $(`&lt;div id=&quot;html_1eb6c26ab412bfbe8dcaa9bc97dd5137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_2f94c4606f2d9fd7ea325a492c6dd83c.setContent(html_1eb6c26ab412bfbe8dcaa9bc97dd5137);
#
#
#
#         marker_7a48efcb3c99eb2fb93a593e5a4f1194.bindPopup(popup_2f94c4606f2d9fd7ea325a492c6dd83c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <a id='toc1_2_'></a>[Using the service](#toc0_)

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[General options](#toc0_)

# %% [markdown]
# The general options are used in every OSRM service, read more about them [here](https://project-osrm.org/docs/v5.5.1/api/?language=cURL#general-options). Here is a table that summarizes the options with their description.
#
#
# | Parameter | Description |
# |-----------|-------------|
# | service | One of the following values: `route`, `nearest`, `table`, `match`, `trip`, `tile` |
# | version | Version of the protocol implemented by the service. `v1` for all OSRM 5.x installations |
# | profile | Mode of transportation, is determined statically by the Lua profile that is used to prepare the data using `osrm-extract`. Typically `car`, `bike` or `foot` if using one of the supplied profiles. |
# | coordinates | String of format `{longitude},{latitude};{longitude},{latitude};{longitude},{latitude} ...]` or `polyline({polyline})`. |
# | format | Only `json` is supported at the moment. This parameter is optional and defaults to `json`. |

# %% [markdown]
# ### <a id='toc1_2_2_'></a>[Making the request](#toc0_)

# %%
service = 'route'
version = 'v1'
profile = 'driving'
host = 'http://localhost:5000'

# %% [markdown]
# The route endpoint follows this format: `/route/v1/{profile}/{coordinates}?alternatives={true|false}&steps={true|false}&geometries={polyline|polyline6|geojson}&overview={full|simplified|false}&annotations={true|false}`.
#
# To request the shortest path between three points, the order of the points is crucial. If you want the route from point 1 to point 2 to point 3, make sure to list them in that sequence.

# %%
import requests

points = [point_1, point_2, point_3]
coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{
    coordinates}?overview=full&steps=true&geometries=geojson"

response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# The `200` status code signifies that the request was successful. Now, let's fetch the route and display it on the map.

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['code', 'routes', 'waypoints'])

# %%
routes = data['routes']
print(f"Found {len(routes)} route(s)")
# Out:
# Found 1 route(s)

# %% [markdown]
# Since we didn't include the `alternatives` option in the request, the response contains only one route. From this route, we can extract the `coordinates`, the `distance` in meters, and the `duration` in seconds.

# %%
route = routes[0]
route_coordinates = route['geometry']["coordinates"]
route_distance = route["distance"]  # unit: meters
route_duration = route["duration"]  # unit: seconds

route_coordinates[:5]
# Out:
# [[-5.500277, 33.892547],
#  [-5.500321, 33.892538],
#  [-5.500521, 33.89249],
#  [-5.500764, 33.892437],
#  [-5.500799, 33.892495]]

# %% [markdown]
# ### <a id='toc1_2_3_'></a>[Plotting the path](#toc0_)

# %% [markdown]
# The route returned by `OSRM` is in the format `[[longitude, latitude], [longitude, latitude], ...]`. To plot the path on the Folium map, we need to swap the latitude and longitude for each point.

# %%
route_coordinates = [[point[1], point[0]] for point in route_coordinates]
route_coordinates[:5]
# Out:
# [[33.892547, -5.500277],
#  [33.892538, -5.500321],
#  [33.89249, -5.500521],
#  [33.892437, -5.500764],
#  [33.892495, -5.500799]]

# %%
folium_map = get_folium_map(center_point, [point_1, point_2, point_3])
popup_text = f"Distance: {route_distance} meters<br>Duration: {
    route_duration} seconds"
popup = folium.Popup(popup_text, max_width=300)

folium.PolyLine(
    locations=route_coordinates, color='blue', weight=5, popup=popup).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af567e97944713fe515d996014cefd46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af567e97944713fe515d996014cefd46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af567e97944713fe515d996014cefd46 = L.map(
#                 &quot;map_af567e97944713fe515d996014cefd46&quot;,
#                 {
#                     center: [33.89565560255, -5.522530349727877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef753e546cc8f77b411e6b2e3c13f431 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef753e546cc8f77b411e6b2e3c13f431.addTo(map_af567e97944713fe515d996014cefd46);
#
#
#             var marker_b0dfdef809e8c0e4a2568d0d0244a3f9 = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_af567e97944713fe515d996014cefd46);
#
#
#         var popup_fb0b6bcc3e2c57fd209a60ef15617956 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e657e444f803bffa5602e974f68b0f12 = $(`&lt;div id=&quot;html_e657e444f803bffa5602e974f68b0f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_fb0b6bcc3e2c57fd209a60ef15617956.setContent(html_e657e444f803bffa5602e974f68b0f12);
#
#
#
#         marker_b0dfdef809e8c0e4a2568d0d0244a3f9.bindPopup(popup_fb0b6bcc3e2c57fd209a60ef15617956)
#         ;
#
#
#
#
#             var marker_df48a081a7570fd8f1a1df63440d4171 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_af567e97944713fe515d996014cefd46);
#
#
#         var popup_e23247521a20ea1a1949cf37272737fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8810508cde07343b53efa863b552ba0e = $(`&lt;div id=&quot;html_8810508cde07343b53efa863b552ba0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_e23247521a20ea1a1949cf37272737fd.setContent(html_8810508cde07343b53efa863b552ba0e);
#
#
#
#         marker_df48a081a7570fd8f1a1df63440d4171.bindPopup(popup_e23247521a20ea1a1949cf37272737fd)
#         ;
#
#
#
#
#             var marker_69ae668f3025cf9f6bef09a8d55a60bb = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_af567e97944713fe515d996014cefd46);
#
#
#         var popup_d36e1ae528f941ad694cc36302d8aa6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51d39578375a805c17efb1dac4cc33a6 = $(`&lt;div id=&quot;html_51d39578375a805c17efb1dac4cc33a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d36e1ae528f941ad694cc36302d8aa6f.setContent(html_51d39578375a805c17efb1dac4cc33a6);
#
#
#
#         marker_69ae668f3025cf9f6bef09a8d55a60bb.bindPopup(popup_d36e1ae528f941ad694cc36302d8aa6f)
#         ;
#
#
#
#
#             var poly_line_12ce3a837035e04499fafdd4a6df297f = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764], [33.892495, -5.500799], [33.892539, -5.500833], [33.892348, -5.500932], [33.892208, -5.501006], [33.892086, -5.501063], [33.891914, -5.50114], [33.891854, -5.501158], [33.891787, -5.501179], [33.891797, -5.501376], [33.891814, -5.501624], [33.891848, -5.502132], [33.891875, -5.502445], [33.891899, -5.502777], [33.891938, -5.503265], [33.891965, -5.503612], [33.891995, -5.50401], [33.892353, -5.503993], [33.892611, -5.503969], [33.892873, -5.503943], [33.893302, -5.5039], [33.893417, -5.50389], [33.893634, -5.50387], [33.893849, -5.503856], [33.89431, -5.503816], [33.894505, -5.503796], [33.894756, -5.503771], [33.894912, -5.503759], [33.894943, -5.503858], [33.894957, -5.503925], [33.895, -5.504012], [33.895052, -5.504089], [33.895205, -5.504285], [33.895365, -5.504496], [33.895439, -5.504588], [33.895622, -5.504826], [33.89582, -5.505078], [33.896122, -5.505486], [33.896254, -5.505656], [33.896299, -5.505715], [33.89635, -5.505783], [33.896492, -5.505966], [33.896609, -5.506117], [33.896658, -5.506178], [33.89671, -5.506244], [33.896802, -5.506358], [33.896865, -5.506446], [33.896984, -5.50664], [33.897045, -5.506754], [33.897115, -5.506898], [33.89716, -5.507004], [33.897207, -5.507091], [33.897278, -5.507201], [33.897321, -5.507266], [33.89739, -5.507345], [33.897454, -5.507404], [33.897563, -5.507484], [33.89775, -5.507588], [33.898006, -5.50773], [33.898441, -5.507986], [33.898601, -5.508054], [33.898638, -5.508069], [33.898933, -5.508248], [33.898958, -5.50825], [33.898981, -5.50826], [33.899002, -5.508276],

# %% [markdown]
# ### <a id='toc1_2_4_'></a>[Exploring legs](#toc0_)

# %% [markdown]
# Each path is referred to as a `leg`. In our case, there are two legs: one that takes us from point 1 to point 2, and the other that connects point 2 to point 3. Each leg contains multiple steps, where each step provides details about how the route changes at a specific point, such as a turn, a continuation in a straight line, or the start/end of the route.

# %% [markdown]
# Let's draw the 2 legs.

# %%
folium_map = get_folium_map(center_point, [point_1, point_2, point_3])

colors = ['black', 'blue']

legs = data["routes"][0]["legs"]
for i, leg in enumerate(legs):
    steps = leg["steps"]
    for step in steps:
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Leg number {i + 1}<br>
        Leg distance: {leg['distance']} meters<br>
        Leg duration: {leg['duration']} seconds<br>
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d2bab478f2ce0e0b67282d5ead3a382 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d2bab478f2ce0e0b67282d5ead3a382&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d2bab478f2ce0e0b67282d5ead3a382 = L.map(
#                 &quot;map_9d2bab478f2ce0e0b67282d5ead3a382&quot;,
#                 {
#                     center: [33.89565560255, -5.522530349727877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7853819f2e316bb14862066863c3a571 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7853819f2e316bb14862066863c3a571.addTo(map_9d2bab478f2ce0e0b67282d5ead3a382);
#
#
#             var marker_067de389ae5b5ed7b0ad9644478cf64f = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_9d2bab478f2ce0e0b67282d5ead3a382);
#
#
#         var popup_d78311d7a988bb57fe06c9012d2ce614 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4f86cda62723e898222e2b48acd5263 = $(`&lt;div id=&quot;html_f4f86cda62723e898222e2b48acd5263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d78311d7a988bb57fe06c9012d2ce614.setContent(html_f4f86cda62723e898222e2b48acd5263);
#
#
#
#         marker_067de389ae5b5ed7b0ad9644478cf64f.bindPopup(popup_d78311d7a988bb57fe06c9012d2ce614)
#         ;
#
#
#
#
#             var marker_43f3229ce294cbc05f7879239c05c435 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_9d2bab478f2ce0e0b67282d5ead3a382);
#
#
#         var popup_4298e069fb0cac5e094d796e05b5a594 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b85b5d11fd41b6fcf81dfb5b96f076d5 = $(`&lt;div id=&quot;html_b85b5d11fd41b6fcf81dfb5b96f076d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_4298e069fb0cac5e094d796e05b5a594.setContent(html_b85b5d11fd41b6fcf81dfb5b96f076d5);
#
#
#
#         marker_43f3229ce294cbc05f7879239c05c435.bindPopup(popup_4298e069fb0cac5e094d796e05b5a594)
#         ;
#
#
#
#
#             var marker_bf0c163c7f57485a168b9a17b207baf8 = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_9d2bab478f2ce0e0b67282d5ead3a382);
#
#
#         var popup_ad289f8d0133fb92c1c9875db5059f65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7776da446bcf7cb65d1564ff63aa4e3c = $(`&lt;div id=&quot;html_7776da446bcf7cb65d1564ff63aa4e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_ad289f8d0133fb92c1c9875db5059f65.setContent(html_7776da446bcf7cb65d1564ff63aa4e3c);
#
#
#
#         marker_bf0c163c7f57485a168b9a17b207baf8.bindPopup(popup_ad289f8d0133fb92c1c9875db5059f65)
#         ;
#
#
#
#
#             var poly_line_3b73da964907d52f094d64dea2aea84d = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_9d2bab478f2ce0e0b67282d5ead3a382);
#
#
#         var popup_7c38ebb69120983fc22a8798612b47f5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3d4ce2700e44cb687d1eec4538366b6b = $(`&lt;div id=&quot;html_3d4ce2700e44cb687d1eec4538366b6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Leg number 1&lt;br&gt;         Leg distance: 2970.2 meters&lt;br&gt;         Leg duration: 253.5 seconds&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_7c38ebb69120983fc22a8798612b47f5.setContent(html_3d4ce2700e44cb687d1eec4538366b6b);
#
#
#
#         poly_line_3b73da964907d52f094d64dea2aea84d.bindPopup(popup_7c38ebb69120983fc22a8798612b47f5)
#         ;
#
#
#
#
#             var poly_line_e1a2c6a7e7b6b093f0eca6b79fe9ea2f = L.polyline(
#                 [[33.892437, -5.500764], [33.892495, -5.500799], [33.892539, -5.500833]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &

# %% [markdown]
# Let's focus on a single leg and break it down into its individual steps. Each step provides instructions on where to go, what action to take, and the distance to travel before transitioning to the next step.
#
# To illustrate, let's consider the first two segments of the leg.

# %%
folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=16)

colors = ['black', 'blue']

legs = data["routes"][0]["legs"]
for leg in legs:
    steps = leg["steps"]
    for i, step in enumerate(steps[:2]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)
    break

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235cdf07208e80322de571dc6944d924 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235cdf07208e80322de571dc6944d924&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235cdf07208e80322de571dc6944d924 = L.map(
#                 &quot;map_235cdf07208e80322de571dc6944d924&quot;,
#                 {
#                     center: [33.89264295626195, -5.500305816538693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bcd0db79612ae1664d97251d3ee89f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8bcd0db79612ae1664d97251d3ee89f5.addTo(map_235cdf07208e80322de571dc6944d924);
#
#
#             var marker_e17dc5307a8d524be253683a62f8c9b0 = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_235cdf07208e80322de571dc6944d924);
#
#
#         var popup_686ad3a0261a0738f2e92c7f94e1eff8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48995de4f53bc6f3ca28afe3a6d492fc = $(`&lt;div id=&quot;html_48995de4f53bc6f3ca28afe3a6d492fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_686ad3a0261a0738f2e92c7f94e1eff8.setContent(html_48995de4f53bc6f3ca28afe3a6d492fc);
#
#
#
#         marker_e17dc5307a8d524be253683a62f8c9b0.bindPopup(popup_686ad3a0261a0738f2e92c7f94e1eff8)
#         ;
#
#
#
#
#             var marker_5ebea2d9f28b2282290223eecaba6503 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_235cdf07208e80322de571dc6944d924);
#
#
#         var popup_2462d1b56f3782bbc83cdf2d6da56418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_766f4b47c9e133446659da7cbebc144e = $(`&lt;div id=&quot;html_766f4b47c9e133446659da7cbebc144e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_2462d1b56f3782bbc83cdf2d6da56418.setContent(html_766f4b47c9e133446659da7cbebc144e);
#
#
#
#         marker_5ebea2d9f28b2282290223eecaba6503.bindPopup(popup_2462d1b56f3782bbc83cdf2d6da56418)
#         ;
#
#
#
#
#             var marker_4a71c261c5b6c2b37a36bb4a52700415 = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_235cdf07208e80322de571dc6944d924);
#
#
#         var popup_5201ff855b1e00b82ef94571cd0fdd0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c9c63976c59d4149646b57724096dd6 = $(`&lt;div id=&quot;html_1c9c63976c59d4149646b57724096dd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_5201ff855b1e00b82ef94571cd0fdd0f.setContent(html_1c9c63976c59d4149646b57724096dd6);
#
#
#
#         marker_4a71c261c5b6c2b37a36bb4a52700415.bindPopup(popup_5201ff855b1e00b82ef94571cd0fdd0f)
#         ;
#
#
#
#
#             var poly_line_72cd676a0c01dd914df6fac0841abd54 = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_235cdf07208e80322de571dc6944d924);
#
#
#         var popup_bb5f99fa2407e0296bbae6be97e79f30 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_6df16355aea1cd63e34c8ee386715533 = $(`&lt;div id=&quot;html_6df16355aea1cd63e34c8ee386715533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 46.7 meters         &lt;br&gt;Duration: 7.6 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: right         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_bb5f99fa2407e0296bbae6be97e79f30.setContent(html_6df16355aea1cd63e34c8ee386715533);
#
#
#
#         poly_line_72cd676a0c01dd914df6fac0841abd54.bindPopup(popup_bb5f99fa2407e0296bbae6be97e79f30)
#         ;
#
#
#
#
#             var poly_line_a77a9991a320f483c297b68dbee23fa4 = L.polyline(
#                 [[33.892437, -5.500764], [33.892495, -5.5

# %% [markdown]
# Each segment contains details such as the `distance`, `duration`, `name` of the road, and other relevant information. This helps to describe the specifics of the route for each step, guiding us on the actions to take and the duration and distance of each segment.

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
pprint(step)
# Out:
# {'distance': 46.7,
#  'driving_side': 'right',
#  'duration': 7.6,
#  'geometry': {'coordinates': [[-5.500277, 33.892547],
#                               [-5.500321, 33.892538],
#                               [-5.500521, 33.89249],
#                               [-5.500764, 33.892437]],
#               'type': 'LineString'},
#  'intersections': [{'bearings': [256],
#                     'entry': [True],
#                     'location': [-5.500277, 33.892547],
#                     'out': 0},
#                    {'bearings': [75, 165, 255],
#                     'entry': [False, True, True],
#                     'in': 0,
#                     'location': [-5.500321, 33.892538],
#                     'out': 2}],
#  'maneuver': {'bearing_after': 256,
#               'bearing_before': 0,
#               'location': [-5.500277, 33.892547],
#               'modifier': 'right',
#               'type': 'depart'},
#  'mode': 'driving',
#  'name': '',
#  'weight': 7.6}

# %% [markdown]
# Let's visualize one step of the route by drawing it on the map. We will display the relevant information as a popup, which can include details such as the distance, duration, road name, etc. Additionally, for the `bearing` angle, we will draw a line in the direction of movement to represent the heading at that point.

# %%
import math


def add_compass(folium_map: Map, location: tuple, bearing: int, size: int = 50):

    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color="red",
        weight=2,
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=16)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        maneuver_location = step["maneuver"]["location"]
        bearing = step["maneuver"].get("bearing_after", 0)
        add_compass(
            folium_map=folium_map,
            location=(maneuver_location[1], maneuver_location[0]),
            bearing=bearing
        )

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e3cfdcbe6acd6916c10bf05f6cdafa0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e3cfdcbe6acd6916c10bf05f6cdafa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e3cfdcbe6acd6916c10bf05f6cdafa0 = L.map(
#                 &quot;map_1e3cfdcbe6acd6916c10bf05f6cdafa0&quot;,
#                 {
#                     center: [33.89264295626195, -5.500305816538693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ea0778830101a33fba549790fbce59b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9ea0778830101a33fba549790fbce59b.addTo(map_1e3cfdcbe6acd6916c10bf05f6cdafa0);
#
#
#             var marker_85c6d667338f903623aa8a18abfb49de = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_1e3cfdcbe6acd6916c10bf05f6cdafa0);
#
#
#         var popup_c4a1af9e4db2f88c653269bd777495d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_319a17e88513a8a01bdbb7be4c5149db = $(`&lt;div id=&quot;html_319a17e88513a8a01bdbb7be4c5149db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_c4a1af9e4db2f88c653269bd777495d4.setContent(html_319a17e88513a8a01bdbb7be4c5149db);
#
#
#
#         marker_85c6d667338f903623aa8a18abfb49de.bindPopup(popup_c4a1af9e4db2f88c653269bd777495d4)
#         ;
#
#
#
#
#             var marker_162060df1e5d992bbdea0721e3deea59 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_1e3cfdcbe6acd6916c10bf05f6cdafa0);
#
#
#         var popup_af9ad9cedda66be38ae7af07f9739322 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b98e8dfe95b42b84c3a87c7ba28d736 = $(`&lt;div id=&quot;html_6b98e8dfe95b42b84c3a87c7ba28d736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_af9ad9cedda66be38ae7af07f9739322.setContent(html_6b98e8dfe95b42b84c3a87c7ba28d736);
#
#
#
#         marker_162060df1e5d992bbdea0721e3deea59.bindPopup(popup_af9ad9cedda66be38ae7af07f9739322)
#         ;
#
#
#
#
#             var marker_1fbad692733b9d5292dcd9d13d8c73eb = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_1e3cfdcbe6acd6916c10bf05f6cdafa0);
#
#
#         var popup_d78f33d50387a03f8cf8ef48d97f3dc4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_302f80c1f09e73ef576dec45c41fd762 = $(`&lt;div id=&quot;html_302f80c1f09e73ef576dec45c41fd762&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d78f33d50387a03f8cf8ef48d97f3dc4.setContent(html_302f80c1f09e73ef576dec45c41fd762);
#
#
#
#         marker_1fbad692733b9d5292dcd9d13d8c73eb.bindPopup(popup_d78f33d50387a03f8cf8ef48d97f3dc4)
#         ;
#
#
#
#
#             var poly_line_3c1438f682dd90cd3f081ff8d0c2784a = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_1e3cfdcbe6acd6916c10bf05f6cdafa0);
#
#
#         var popup_90b5a748422c81053276e46a7cd98859 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e5d48ed124745ccb524e1315c2fc9094 = $(`&lt;div id=&quot;html_e5d48ed124745ccb524e1315c2fc9094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 46.7 meters         &lt;br&gt;Duration: 7.6 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: right         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_90b5a748422c81053276e46a7cd98859.setContent(html_e5d48ed124745ccb524e1315c2fc9094);
#
#
#
#         poly_line_3c1438f682dd90cd3f081ff8d0c2784a.bindPopup(popup_90b5a748422c81053276e46a7cd98859)
#         ;
#
#
#
#
#             var marker_1f3c504c4f705056e93abc74f23558a3 = L.marker(
#                 [33.892547, -5.500277],
#                 {}

# %% [markdown]
# ### <a id='toc1_2_5_'></a>[Exploring the intersections](#toc0_)

# %% [markdown]
# Let’s explain what the values for `intersection` represent. Starting with the first step in the first leg, we encounter 2 objects, each providing detailed information about the road layout at the intersection.
#
# - `out`: This indicates the index of the outgoing bearing from the intersection. In the first object, `out` is 0 because there is only one available bearing angle. In the second object, `out` is 2, as there are three possible options to choose from.
# - `in`: The index of the incoming bearing, representing the road you arrived on.
# - `entry`: A list of booleans, where each value corresponds to a `bearing` in the bearings array. A `True` value means the road is accessible, while a `False` value means it is not.
# - `bearings`: An array of compass bearings (in degrees) that represent all the possible directions (roads) at this intersection. Each bearing corresponds to a road radiating out from the intersection.
# - `location`: The precise [longitude, latitude] coordinates of the intersection.

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
intersections = step["intersections"]
pprint(intersections)
# Out:
# [{'bearings': [256],
#   'entry': [True],
#   'location': [-5.500277, 33.892547],
#   'out': 0},
#  {'bearings': [75, 165, 255],
#   'entry': [False, True, True],
#   'in': 0,
#   'location': [-5.500321, 33.892538],
#   'out': 2}]

# %% [markdown]
# Let's plot the `bearing` directions on the map to visualize what these values represent. The first intersection object contains only one bearing value, indicating that there is only one option to choose from.

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=18)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[:1]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02c7c4a3f5f35ce1649c6b0c2245fdf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02c7c4a3f5f35ce1649c6b0c2245fdf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02c7c4a3f5f35ce1649c6b0c2245fdf6 = L.map(
#                 &quot;map_02c7c4a3f5f35ce1649c6b0c2245fdf6&quot;,
#                 {
#                     center: [33.89264295626195, -5.500305816538693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f38c90c039dfce2c54a733252c3352db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f38c90c039dfce2c54a733252c3352db.addTo(map_02c7c4a3f5f35ce1649c6b0c2245fdf6);
#
#
#             var marker_2b8c910698d73ead4b37652132f8c42f = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_02c7c4a3f5f35ce1649c6b0c2245fdf6);
#
#
#         var popup_6caea117bd57c52bd8a76d3e304b90b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c2fb48cd9a03a491198c6cc6cf204fc = $(`&lt;div id=&quot;html_4c2fb48cd9a03a491198c6cc6cf204fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_6caea117bd57c52bd8a76d3e304b90b4.setContent(html_4c2fb48cd9a03a491198c6cc6cf204fc);
#
#
#
#         marker_2b8c910698d73ead4b37652132f8c42f.bindPopup(popup_6caea117bd57c52bd8a76d3e304b90b4)
#         ;
#
#
#
#
#             var marker_fc57df250f8cae0ea576d8a115836706 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_02c7c4a3f5f35ce1649c6b0c2245fdf6);
#
#
#         var popup_8093e37aca80d290f278d7a7a231f1e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43cb1c35aa6636facdb4265046c0cbbc = $(`&lt;div id=&quot;html_43cb1c35aa6636facdb4265046c0cbbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_8093e37aca80d290f278d7a7a231f1e8.setContent(html_43cb1c35aa6636facdb4265046c0cbbc);
#
#
#
#         marker_fc57df250f8cae0ea576d8a115836706.bindPopup(popup_8093e37aca80d290f278d7a7a231f1e8)
#         ;
#
#
#
#
#             var marker_e6124718aa024e9d01faf3f5eadc3fce = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_02c7c4a3f5f35ce1649c6b0c2245fdf6);
#
#
#         var popup_ee2f3255d758bf44d56e9d60a2f27091 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78030955df229194d3cfd1842a69d6de = $(`&lt;div id=&quot;html_78030955df229194d3cfd1842a69d6de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_ee2f3255d758bf44d56e9d60a2f27091.setContent(html_78030955df229194d3cfd1842a69d6de);
#
#
#
#         marker_e6124718aa024e9d01faf3f5eadc3fce.bindPopup(popup_ee2f3255d758bf44d56e9d60a2f27091)
#         ;
#
#
#
#
#             var poly_line_f41b6c490219b7dafeb8820d821884a2 = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_02c7c4a3f5f35ce1649c6b0c2245fdf6);
#
#
#         var popup_00351b6854b468883e1d069e887e469d = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_cd9152da551154c0a8e1fa3e9dff4dc4 = $(`&lt;div id=&quot;html_cd9152da551154c0a8e1fa3e9dff4dc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 46.7 meters         &lt;br&gt;Duration: 7.6 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: right         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_00351b6854b468883e1d069e887e469d.setContent(html_cd9152da551154c0a8e1fa3e9dff4dc4);
#
#
#
#         poly_line_f41b6c490219b7dafeb8820d821884a2.bindPopup(popup_00351b6854b468883e1d069e887e469d)
#         ;
#
#
#
#
#             var marker_8d8e61d74c912d0904d00cf54db62fc8 = L.marker(
#                 [33.892547, -5.500277],
#                 {}

# %% [markdown]
# After a few steps, we encounter an intersection with three bearing values. These correspond to going straight, turning back, or turning left. The `entry` value for the first bearing, which corresponds to going back, is set to `False`, meaning we cannot reverse our direction. The other two routes, however, can be taken because their `entry` values are set to `True`.

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: black;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°"
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2, point_3], zoom_level=20)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[1:]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aaf90463e4827adc61f71ea20639c7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aaf90463e4827adc61f71ea20639c7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aaf90463e4827adc61f71ea20639c7a = L.map(
#                 &quot;map_8aaf90463e4827adc61f71ea20639c7a&quot;,
#                 {
#                     center: [33.89264295626195, -5.500305816538693],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e0d0fa184865d3295ba0f944255ffac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7e0d0fa184865d3295ba0f944255ffac.addTo(map_8aaf90463e4827adc61f71ea20639c7a);
#
#
#             var marker_129989d9d02eca4a8ab1dd3b7d1f6f48 = L.marker(
#                 [33.89264295626195, -5.500305816538693],
#                 {}
#             ).addTo(map_8aaf90463e4827adc61f71ea20639c7a);
#
#
#         var popup_c31f3d0af7b1e66b6f79f21e2d881843 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33566481544804a9d928fa02a89c674b = $(`&lt;div id=&quot;html_33566481544804a9d928fa02a89c674b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_c31f3d0af7b1e66b6f79f21e2d881843.setContent(html_33566481544804a9d928fa02a89c674b);
#
#
#
#         marker_129989d9d02eca4a8ab1dd3b7d1f6f48.bindPopup(popup_c31f3d0af7b1e66b6f79f21e2d881843)
#         ;
#
#
#
#
#             var marker_221f79faf8681282f3ccaf243ef7bc58 = L.marker(
#                 [33.899915132942326, -5.520818749583605],
#                 {}
#             ).addTo(map_8aaf90463e4827adc61f71ea20639c7a);
#
#
#         var popup_d6e6ab45739e35434d71c4b14d71c0d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c8898d01411fd0c0cab24e757cee754 = $(`&lt;div id=&quot;html_6c8898d01411fd0c0cab24e757cee754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d6e6ab45739e35434d71c4b14d71c0d6.setContent(html_6c8898d01411fd0c0cab24e757cee754);
#
#
#
#         marker_221f79faf8681282f3ccaf243ef7bc58.bindPopup(popup_d6e6ab45739e35434d71c4b14d71c0d6)
#         ;
#
#
#
#
#             var marker_4d28c7251157f6b7769ea5f455a437c4 = L.marker(
#                 [33.891645357611154, -5.5397637571355105],
#                 {}
#             ).addTo(map_8aaf90463e4827adc61f71ea20639c7a);
#
#
#         var popup_ddda90a4db70f045604b8d6fcb84206b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f26b6949cbb08dfbac2af6b047e08411 = $(`&lt;div id=&quot;html_f26b6949cbb08dfbac2af6b047e08411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_ddda90a4db70f045604b8d6fcb84206b.setContent(html_f26b6949cbb08dfbac2af6b047e08411);
#
#
#
#         marker_4d28c7251157f6b7769ea5f455a437c4.bindPopup(popup_ddda90a4db70f045604b8d6fcb84206b)
#         ;
#
#
#
#
#             var poly_line_fc680186341304b6b5238ca287ab6e97 = L.polyline(
#                 [[33.892547, -5.500277], [33.892538, -5.500321], [33.89249, -5.500521], [33.892437, -5.500764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_8aaf90463e4827adc61f71ea20639c7a);
#
#
#         var popup_140e6f2614151d508682996c96addadd = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_673bf66935322f54aa76e3f370b2b61e = $(`&lt;div id=&quot;html_673bf66935322f54aa76e3f370b2b61e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Distance: 46.7 meters         &lt;br&gt;Duration: 7.6 seconds         &lt;br&gt;Name:          &lt;br&gt;Driving side: right         &lt;br&gt;Instruction: right         &lt;br&gt;Type of maneuver: depart         &lt;br&gt;Intersections: 2         &lt;/div&gt;`)[0];
#                 popup_140e6f2614151d508682996c96addadd.setContent(html_673bf66935322f54aa76e3f370b2b61e);
#
#
#
#         poly_line_fc680186341304b6b5238ca287ab6e97.bindPopup(popup_140e6f2614151d508682996c96addadd)
#         ;
#
#
#
#
#             var marker_3a0708d280509349cd5b6c6d3da6e7a4 = L.marker(
#                 [33.892538, -5.500321],
#                 {}

# %% [markdown]
# ### <a id='toc1_2_6_'></a>[Exploring the cost of the route](#toc0_)

# %% [markdown]
# Now, let's discuss `weights`. The `weight` value represents the cost of the route based on the profile's weighting algorithm. In this case, the weight is 499.8. With the default profile, the weight corresponds to the route's duration, but this can be modified in the `car` profile, which you can find [here](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/car.lua#L23).
#
# If you're using a different profile, such as the [bike](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/bicycle.lua#L22) or [foot](https://github.com/Project-OSRM/osrm-backend/blob/master/profiles/foot.lua#L14) profiles, make sure to adjust the respective files.

# %%
weight = route["weight"]
weight_name = route["weight_name"]
duration = route["duration"]
distance = route["distance"]

print(f"Weight: {weight} - {weight_name}")
print(f"Duration: {duration} seconds")
print(f"Distance: {distance} meters")
# Out:
# Weight: 499.8 - routability
# Duration: 499.8 seconds
# Distance: 6042.4 meters

# %% [markdown]
# ### <a id='toc1_2_7_'></a>[Alternative routes](#toc0_)

# %% [markdown]
# By default, OSRM provides a single route corresponding to the shortest path. To view alternative routes, you need to enable the `alternatives` option and specify the number of alternatives you'd like to receive.
#
# Note: Although you can request alternative routes, there is no guarantee that they will be available.

# %%
import requests

points = [point_1, point_2, point_3]
coordinates = ';'.join(
    [f'{point.longitude},{point.latitude}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{
    coordinates}?alternatives=3&overview=full&steps=true&geometries=geojson"

response = requests.get(url)
data = response.json()
routes = data['routes']
print(f"Found {len(routes)} route(s)")
# Out:
# Found 1 route(s)

# %% [markdown]
# The note confirms that even with `alternatives` set to 3, only one route was returned. However, if you're interested, you can modify certain values in the source code to force OSRM to return an alternative route. For more details, check this [thread](https://github.com/Project-OSRM/osrm-backend/issues/5663).
